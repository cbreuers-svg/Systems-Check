# %%
 https://www.kaggle.com/datasets/rush4ratio/video-game-sales-with-ratings

# %% [markdown]
# ### Analysis Plan
#
# This project will  investigate the complex relationship between critical acclaim and commercial success in the video game industry. The analysis begins with a  phase of Data Understanding and Cleaning, where we will explore the dataset's structure, handle missing values in review scores and sales figures, and identify the key variables—Critic_Score, User_Score, Global_Sales, and Genre—that form the foundation. Following this, the Exploratory Data Analysis will paint a broad picture of the landscape, revealing the distribution of review scores and sales, highlighting which genres tend to be the most commercially successful, and providing initial visual evidence of the relationship between scores and sales through scatter plots. The core of the investigation lies in the Statistical Analysis, Next, we'll test our observations with numbers. We'll calculate how strongly review scores and sales are related, and check if this pattern holds true for all types of games. Finally, all these insights will be synthesized through Visualization, using clear and compelling charts like scatter plots, genre wise comparison bars, and sales distribution histograms to tell the story of whether a high score truly translates into a best-selling game.

# %% [markdown]
# i have a samle of the data right here, as the data at my disposal is alot and i am working on how to translate it

# %%
print("Creating sample dataset for testing...")
sample_data = {
    'Name': ['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', 'Wii Sports Resort', 'Pokemon Red/Pokemon Blue'],
    'Platform': ['Wii', 'NES', 'Wii', 'Wii', 'GB'],
    'Year_of_Release': [2006, 1985, 2008, 2009, 1996],
    'Genre': ['Sports', 'Platform', 'Racing', 'Sports', 'Role-Playing'],
    'Publisher': ['Nintendo', 'Nintendo', 'Nintendo', 'Nintendo', 'Nintendo'],
    'NA_Sales': [41.36, 29.08, 15.68, 15.61, 11.27],
    'EU_Sales': [28.96, 3.58, 12.76, 10.93, 8.89],
    'JP_Sales': [3.77, 6.81, 3.79, 3.28, 10.22],
    'Other_Sales': [8.45, 0.77, 3.29, 2.95, 1.0],
    'Global_Sales': [82.53, 40.24, 35.52, 32.77, 31.37],
    'Critic_Score': [76, None, 82, 80, None],
    'User_Score': [8.0, None, 8.3, 8.0, None]
}

df = pd.DataFrame(sample_data)
print("Sample dataset created!")
print("Dataset shape:", df.shape)
print("\nFirst few rows:")
print(df.head())
print("\nColumn info:")
print(df.info())
# Out:
# Creating sample dataset for testing...
# Sample dataset created!
# Dataset shape: (5, 12)
#
# First few rows:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii             2006        Sports  Nintendo
# 1         Super Mario Bros.      NES             1985      Platform  Nintendo
# 2            Mario Kart Wii      Wii             2008        Racing  Nintendo
# 3         Wii Sports Resort      Wii             2009        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# ...

# %%
print("Dataset Overview:")
print(f"Total games: {len(df)}")
print(f"Columns: {df.columns.tolist()}")
print(f"Years range: {df['Year_of_Release'].min()} - {df['Year_of_Release'].max()}")
print(f"Number of genres: {df['Genre'].nunique()}")
print(f"Genres: {df['Genre'].unique()}")

print("\nMissing values:")
missing_data = df.isnull().sum()
print(missing_data[missing_data > 0])
# Out:
# Dataset Overview:
# Total games: 5
# Columns: ['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score', 'User_Score']
# Years range: 1985 - 2009
# Number of genres: 4
# Genres: ['Sports' 'Platform' 'Racing' 'Role-Playing']
#
# Missing values:
# Critic_Score    2
# User_Score      2
# dtype: int64

# %%
analysis_df = df[['Name', 'Genre', 'Global_Sales', 'Critic_Score', 'User_Score']].copy()

analysis_df['User_Score'] = pd.to_numeric(analysis_df['User_Score'], errors='coerce')

print("Data after cleaning:")
print(f"Total games with critic scores: {analysis_df['Critic_Score'].notna().sum()}")
print(f"Total games with user scores: {analysis_df['User_Score'].notna().sum()}")
print(f"Total games with sales data: {analysis_df['Global_Sales'].notna().sum()}")

complete_data = analysis_df.dropna(subset=['Critic_Score', 'User_Score', 'Global_Sales'])
print(f"\nComplete records for analysis: {len(complete_data)}")
# Out:
# Data after cleaning:
# Total games with critic scores: 3
# Total games with user scores: 3
# Total games with sales data: 5
#
# Complete records for analysis: 3
